# %%
from feda_tools import twodim_hist

# %%
x = [0,1,2,3,4,5]
y = [0,1,2,3,4,5]

# %%
fig,ax = twodim_hist.make_plot(x, y, "x", "auto", "y")

# %%
for subplot in [ax, ax.inset_axes([0, 1.05, 1.0, 0.25], sharex=ax), ax.inset_axes([1.05, 0, 0.25, 1], sharey=ax)]:
    subplot.
# Out:
# Axes(0.195056,0.12801;0.602407x0.661179)
# Axes(0.195056,0.822248;0.602407x0.165295)
# Axes(0.827583,0.12801;0.150602x0.661179)
